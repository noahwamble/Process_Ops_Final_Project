# %% [markdown]
# # Scheduling Multipurpose Batch Processes using State-Task Networks
# ## By Pete Giannini and Noah Wamble
#
# Keywords:state-task networks, gdp, disjunctive programming, batch processes
#
# The State-Task Network (STN) is an approach to modeling multipurpose batch process for the purpose of short term scheduling. It was first developed by Kondili, et al., in 1993, and subsequently developed and extended by others. This notebook will look at scheduling jobs in a small craft brewery.

# %% [markdown]
# ## Imports

# %%
# !conda install -c conda-forge ipopt glpk
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display, HTML
    
import shutil
import sys
import os.path

from pyomo.environ import *

# %% [markdown]
# ## Example (Kondili, et al., 1993)
#
# A state-task network is a graphical representation of the activities in a multiproduct batch process. The representation includes the minimum details needed for short term scheduling of batch operations.
#
# A well-studied example due to Kondili (1993) is shown below. Other examples are available in the references cited above.
#
# ![Kondili_1993.png](https://github.com/jckantor/ND-Pyomo-Cookbook/blob/master/notebooks/figures/Kondili_1993.png?raw=1)
#
# Each circular node in the diagram designates material in a particular state.  The materials are generally held in suitable vessels with a known capacity. The relevant information for each state is the initial inventory, storage capacity, and the unit price of the material in each state. The price of materials in intermediate states may be assigned penalities in order to minimize the amount of work in progress.
#
# The rectangular nodes denote process tasks. When scheduled for execution, each task is assigned an appropriate piece of equipment, and assigned a batch of material according to the incoming arcs. Each incoming arc begins at a state where the associated label indicates the mass fraction of the batch coming from that particular state. Outgoing arcs indicate the disposition of the batch to product states. The outgoing are labels indicate the fraction of the batch assigned to each product state, and the time necessary to produce that product.
#
# Not shown in the diagram is the process equipment used to execute the tasks. A separate list of process units is available, each characterized by a capacity and list of tasks which can be performed in that unit.

# %% [markdown]
# ## Encoding the STN data
#
# The basic data structure specifies the states, tasks, and units comprising a state-task network. The intention is for all relevant problem data to be contained in a single JSON-like structure.

# %%
# planning horizon
H = 10

Kondili = {
    # time grid
    'TIME':  range(0, H+1),
    
    # states
    'STATES': {
        'Feed_A'   : {'capacity': 500, 'initial': 500, 'price':  0},
        'Feed_B'   : {'capacity': 500, 'initial': 500, 'price':  0},
        'Feed_C'   : {'capacity': 500, 'initial': 500, 'price':  0},
        'Hot_A'    : {'capacity': 100, 'initial':   0, 'price': -100},
        'Int_AB'   : {'capacity': 200, 'initial':   0, 'price': -100},
        'Int_BC'   : {'capacity': 150, 'initial':   0, 'price': -100},
        'Impure_E' : {'capacity': 100, 'initial':   0, 'price': -100},
        'Product_1': {'capacity': 500, 'initial':   0, 'price': 10},
        'Product_2': {'capacity': 500, 'initial':   0, 'price': 10},
    },
    
    # state-to-task arcs indexed by (state, task)
    'ST_ARCS': {
        ('Feed_A',   'Heating')   : {'rho': 1.0},
        ('Feed_B',   'Reaction_1'): {'rho': 0.5},
        ('Feed_C',   'Reaction_1'): {'rho': 0.5},
        ('Feed_C',   'Reaction_3'): {'rho': 0.2},
        ('Hot_A',    'Reaction_2'): {'rho': 0.4},
        ('Int_AB',   'Reaction_3'): {'rho': 0.8},
        ('Int_BC',   'Reaction_2'): {'rho': 0.6},
        ('Impure_E', 'Separation'): {'rho': 1.0},
    },
    
    # task-to-state arcs indexed by (task, state)
    'TS_ARCS': {
        ('Heating',    'Hot_A')    : {'dur': 1, 'rho': 1.0},
        ('Reaction_2', 'Product_1'): {'dur': 2, 'rho': 0.4},
        ('Reaction_2', 'Int_AB')   : {'dur': 2, 'rho': 0.6},
        ('Reaction_1', 'Int_BC')   : {'dur': 2, 'rho': 1.0},
        ('Reaction_3', 'Impure_E') : {'dur': 1, 'rho': 1.0},
        ('Separation', 'Int_AB')   : {'dur': 2, 'rho': 0.1},
        ('Separation', 'Product_2'): {'dur': 1, 'rho': 0.9},
    },
    
    # unit data indexed by (unit, task)
    'UNIT_TASKS': {
        ('Heater',    'Heating')   : {'Bmin': 0, 'Bmax': 100, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Reactor_1', 'Reaction_1'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Reactor_1', 'Reaction_2'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Reactor_1', 'Reaction_3'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Reactor_2', 'Reaction_1'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Reactor_2', 'Reaction_2'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Reactor_2', 'Reaction_3'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Still',     'Separation'): {'Bmin': 0, 'Bmax': 200, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
    },
}

STN = Kondili

# %%
#What is rho in these models? 



#Planning horizon 
H=10

brewery = {
    # time grid
    'TIME':  range(0, H+1),
    
    # states
    'STATES': {
        #main feeds 
        'Feed_A'   : {'capacity': 500, 'initial': 500, 'price':  0},
        'Feed_B'   : {'capacity': 500, 'initial': 500, 'price':  0},
        'mash'    : {'capacity': 100, 'initial':   0, 'price': -100},
        'husk'   : {'capacity': 200, 'initial':   0, 'price': 0},
        
        #this is the liquid after the lautering step 
        'wort'   : {'capacity': 150, 'initial':   0, 'price': -100},
        
        #this is the wort after the boiling step 
        'wort_heated': {'capacity': 150, 'initial': 0, 'price': -100},
        
        #this is after the separation step 
        'wort_separated' : {'capacity': 150, 'initial':   0, 'price': -100},
        
        #this is the waste product from the separator 
        'malt' : {'capacity': 100, 'initial':   0, 'price': -10},
        
        #brights 
        'bright_A': {'capacity': 500, 'initial':   0, 'price': -100},
        'bright_B': {'capacity': 500, 'initial':   0, 'price': -100},
        'bright_C': {'capacity': 500, 'initial':   0, 'price': -100},
        
        #state before canning/kegging 
        'pre_packaged_A': {'capacity': 500, 'initial':   0, 'price': -150},
        'pre_packaged_B': {'capacity': 500, 'initial':   0, 'price': -150},
        'pre_packaged_C': {'capacity': 500, 'initial':   0, 'price': -150},

        
        #final product 
        'canned_A': {'capacity': 500, 'initial':   0, 'price': 10},
        'canned_B': {'capacity': 500, 'initial':   0, 'price': 10},
        'canned_C': {'capacity': 500, 'initial':   0, 'price': 10},
        'keg_A': {'capacity': 500, 'initial':   0, 'price': 100},
        'keg_B': {'capacity': 500, 'initial':   0, 'price': 100},
        'keg_C': {'capacity': 500, 'initial':   0, 'price': 100},

    },
    
    # state-to-task arcs indexed by (state, task)
    'ST_ARCS': {
        ('Feed_A',   'Heating_conversion')   : {'rho': 1.0},
        ('Feed_B',   'kettle'): {'rho': 0.5},
        ('mash',   'lautering'): {'rho': 0.5},
        ('wort',   'kettle'): {'rho': 0.2},
        ('wort_heated', 'separator'): {'rho': .2},
        ('wort_separated',    'Reaction_A'): {'rho': 0.4},
        ('wort_separated',    'Reaction_B'): {'rho': 0.4},
        ('wort_separated',    'Reaction_C'): {'rho': 0.4},

        #we want it such that any product can go into any bright tank as it is just a holding tank 
        ('bright_A',    'bright_tank'): {'rho': 0.4},
        ('bright_B',    'bright_tank'): {'rho': 0.4},
        ('bright_C',    'bright_tank'): {'rho': 0.4},
        ('pre_packaged_A',    'can_line'): {'rho': 0.4},
        ('pre_packaged_B',    'can_line'): {'rho': 0.4},
        ('pre_packaged_C',    'can_line'): {'rho': 0.4},
        ('pre_packaged_A',    'keg_line'): {'rho': 0.4},
        ('pre_packaged_B',    'keg_line'): {'rho': 0.4},
        ('pre_packaged_C',    'keg_line'): {'rho': 0.4},  
    },
    
    # task-to-state arcs indexed by (task, state)
    'TS_ARCS': {
       #preparation of pre-fermentated mix 
        ('Heating_conversion',    'mash')    : {'dur': 1, 'rho': 1.0},
        ('lautering', 'wort'): {'dur': 2, 'rho': 0.4},
        ('kettle', 'wort_heated')   : {'dur': 2, 'rho': 0.6},
        ('separator', 'wort_separated'): {'dur': 2, 'rho': .6},
        ('separator', 'malt')   : {'dur': 2, 'rho': 0.6},
        
        #fermentation 
        ('Reaction_A', 'bright_A')   : {'dur': 5, 'rho': 1.0},
        ('Reaction_B', 'bright_B') : {'dur': 5, 'rho': 1.0},
        ('Reaction_C', 'bright_C') : {'dur': 10, 'rho': 1.0},
        #holding tank 
        ('bright_tank', 'pre_packaged_A'): {'dur': 0, 'rho': 1},
        ('bright_tank', 'pre_packaged_B'): {'dur': 0, 'rho': 1},
        ('bright_tank', 'pre_packaged_C'): {'dur': 0, 'rho': 1},
        #canning operation 
        ('can_line', 'canned_A')   : {'dur': 2, 'rho': 0.1},
        ('can_line', 'canned_B')   : {'dur': 2, 'rho': 0.1},
        ('can_line', 'canned_C')   : {'dur': 2, 'rho': 0.1},
        #Kegging operationg 
        ('keg_line', 'keg_C')   : {'dur': 2, 'rho': 0.1},
        ('keg_line', 'keg_B')   : {'dur': 2, 'rho': 0.1},
        ('keg_line', 'keg_A')   : {'dur': 2, 'rho': 0.1},
    },
    
    # unit data indexed by (unit, task)
    'UNIT_TASKS': {
        ('Mash Heater',    'Heating_conversion')   : {'Bmin': 0, 'Bmax': 100, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Lauter', 'lautering'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Kettle_drum', 'kettle'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Separator_tank', 'separator'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
       
        
        #this fermenter can do any of the fermentation reactions 
        ('Fermenter_1', 'Reaction_A'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Fermenter_1', 'Reaction_B'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Fermenter_1', 'Reaction_C'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},

        #this fermenter can do any of the fermentation reactions 
        ('Fermenter_2', 'Reaction_A'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},       
        ('Fermenter_2', 'Reaction_B'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('Fermenter_2', 'Reaction_C'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},

        #bright from any reaction can be put in any bright tank 
        ('bright_1', 'bright_tank'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('bright_2', 'bright_tank'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('bright_3', 'bright_tank'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        
        #there is only one keg line and only one can line 
        ('canner', 'can_line'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},
        ('kegger', 'keg_line'): {'Bmin': 0, 'Bmax':  80, 'Cost': 1, 'vCost': 0, 'Tclean': 0},

        
    },
}
STN= brewery

# %% [markdown]
# ### Setting a time grid
#
# The following computations can be done on any time grid, including real-valued time points. TIME is a list of time points commencing at 0.

# %% [markdown]
# ## Creating a Pyomo model
#
# The following Pyomo model closely follows the development in Kondili, et al. (1993). In particular, the first step in the model is to process the STN data to create sets as given in Kondili.
#
# One important difference from Kondili is the adoption of a more natural time scale that starts at $t = 0$ and extends to $t = H$ (rather than from 1 to H+1).
#
# A second difference is the introduction of an additional decision variable denoted by $Q_{j,t}$ indicating the amount of material in unit $j$ at time $t$. A material balance then reads
#
# \begin{align*}
# Q_{jt} & = Q_{j(t-1)} + \sum_{i\in I_j}B_{ijt} - \sum_{i\in I_j}\sum_{\substack{s \in \bar{S}_i\\s\ni t-P_{is} \geq 0}}\bar{\rho}_{is}B_{ij(t-P_{is})} \qquad \forall j,t
# \end{align*}
#
# Following Kondili's notation, $I_j$ is the set of tasks that can be performed in unit $j$, and $\bar{S}_i$ is the set of states fed by task $j$. We assume the units are empty at the beginning and end of production period, i.e.,
#
# \begin{align*}
# Q_{j(-1)} & = 0 \qquad \forall j \\
# Q_{j,H} & = 0 \qquad \forall j
# \end{align*}
#
# The unit allocation constraints are written the full backward aggregation method described by Shah (1993).  The allocation constraint reads
#
# \begin{align*}
# \sum_{i \in I_j} \sum_{t'=t}^{t-p_i+1} W_{ijt'} & \leq 1 \qquad \forall j,t
# \end{align*}
#
# Each processing unit $j$ is tagged with a minimum and maximum capacity, $B_{ij}^{min}$ and $B_{ij}^{max}$, respectively, denoting the minimum and maximum batch sizes for each task $i$. A minimum capacity may be needed to cover heat exchange coils in a reactor or mixing blades in a blender, for example. The capacity may depend on the nature of the task being performed.  These constraints are written
#
# \begin{align*}
# B_{ij}^{min}W_{ijt} & \leq B_{ijt} \leq  B_{ij}^{max}W_{ijt} \qquad \forall j, \forall i\in I_j, \forall t
# \end{align*}

# %% [markdown]
# ### Characterization of tasks

# %%
STATES = STN['STATES']
ST_ARCS = STN['ST_ARCS']
TS_ARCS = STN['TS_ARCS']
UNIT_TASKS = STN['UNIT_TASKS']
TIME = STN['TIME']
H = max(TIME)
# print(STATES)
# print(ST_ARCS)
# print(TS_ARCS)

# %%
# set of tasks
TASKS = set([i for (j,i) in UNIT_TASKS])

# S[i] input set of states which feed task i
S = {i: set() for i in TASKS}
for (s,i) in ST_ARCS:
    S[i].add(s)

# S_[i] output set of states fed by task i
S_ = {i: set() for i in TASKS}
for (i,s) in TS_ARCS:
    S_[i].add(s)

# rho[(i,s)] input fraction of task i from state s
rho = {(i,s): ST_ARCS[(s,i)]['rho'] for (s,i) in ST_ARCS}

# rho_[(i,s)] output fraction of task i to state s
rho_ = {(i,s): TS_ARCS[(i,s)]['rho'] for (i,s) in TS_ARCS}

# P[(i,s)] time for task i output to state s 
P = {(i,s): TS_ARCS[(i,s)]['dur'] for (i,s) in TS_ARCS}

# p[i] completion time for task i
p = {i: max([P[(i,s)] for s in S_[i]]) for i in TASKS}

# K[i] set of units capable of task i
K = {i: set() for i in TASKS}
for (j,i) in UNIT_TASKS:
    K[i].add(j)

# %% [markdown]
# ### Characterization of states

# %%
# T[s] set of tasks receiving material from state s
T = {s: set() for s in STATES}

for (s,i) in ST_ARCS:
    T[s].add(i)

# set of tasks producing material for state s
T_ = {s: set() for s in STATES}
for (i,s) in TS_ARCS:
    T_[s].add(i)

# C[s] storage capacity for state s
C = {s: STATES[s]['capacity'] for s in STATES}

# %% [markdown]
# ### Characterization of units

# %%
UNITS = set([j for (j,i) in UNIT_TASKS])

# I[j] set of tasks performed with unit j
I = {j: set() for j in UNITS}
for (j,i) in UNIT_TASKS:
    I[j].add(i)

# Bmax[(i,j)] maximum capacity of unit j for task i
Bmax = {(i,j):UNIT_TASKS[(j,i)]['Bmax'] for (j,i) in UNIT_TASKS}

# Bmin[(i,j)] minimum capacity of unit j for task i
Bmin = {(i,j):UNIT_TASKS[(j,i)]['Bmin'] for (j,i) in UNIT_TASKS}

# %% [markdown]
# ### Pyomo model

# %%
TIME = np.array(TIME)

model = ConcreteModel()

# W[i,j,t] 1 if task i starts in unit j at time t
model.W = Var(TASKS, UNITS, TIME, domain=Boolean)

# B[i,j,t,] size of batch assigned to task i in unit j at time t
model.B = Var(TASKS, UNITS, TIME, domain=NonNegativeReals)

# S[s,t] inventory of state s at time t
model.S = Var(STATES.keys(), TIME, domain=NonNegativeReals)

# Q[j,t] inventory of unit j at time t
model.Q = Var(UNITS, TIME, domain=NonNegativeReals)

# Objective function

# project value
model.Value = Var(domain=NonNegativeReals)
model.valuec = Constraint(expr = model.Value == sum([STATES[s]['price']*model.S[s,H] for s in STATES]))

# project cost
model.Cost = Var(domain=NonNegativeReals)
model.costc = Constraint(expr = model.Cost == sum([UNIT_TASKS[(j,i)]['Cost']*model.W[i,j,t] +
        UNIT_TASKS[(j,i)]['vCost']*model.B[i,j,t] for i in TASKS for j in K[i] for t in TIME])) 

model.obj = Objective(expr = model.Value - model.Cost, sense = maximize)

# Constraints
model.cons = ConstraintList()

# a unit can only be allocated to one task 
for j in UNITS:
    for t in TIME:
        lhs = 0
        for i in I[j]:
            for tprime in TIME:
                if tprime >= (t-p[i]+1-UNIT_TASKS[(j,i)]['Tclean']) and tprime <= t:
                    lhs += model.W[i,j,tprime]
        model.cons.add(lhs <= 1)
        model.cons.pprint()
    
# state capacity constraint
model.sc = Constraint(STATES.keys(), TIME, rule = lambda model, s, t: model.S[s,t] <= C[s])

# state mass balances
for s in STATES.keys():
    rhs = STATES[s]['initial']
    for t in TIME:
        for i in T_[s]:
            for j in K[i]:
                if t >= P[(i,s)]: 
                    rhs += rho_[(i,s)]*model.B[i,j,max(TIME[TIME <= t-P[(i,s)]])]             
        for i in T[s]:
            rhs -= rho[(i,s)]*sum([model.B[i,j,t] for j in K[i]])
        model.cons.add(model.S[s,t] == rhs)
        rhs = model.S[s,t] 
    
# unit capacity constraints
for t in TIME:
    for j in UNITS:
        for i in I[j]:
            model.cons.add(model.W[i,j,t]*Bmin[i,j] <= model.B[i,j,t])
            model.cons.add(model.B[i,j,t] <= model.W[i,j,t]*Bmax[i,j]) 

# unit mass balances
for j in UNITS:
    rhs = 0
    for t in TIME:
        rhs += sum([model.B[i,j,t] for i in I[j]])
        for i in I[j]:
            for s in S_[i]:
                if t >= P[(i,s)]:
                    rhs -= rho_[(i,s)]*model.B[i,j,max(TIME[TIME <= t-P[(i,s)]])]
        model.cons.add(model.Q[j,t] == rhs)
        rhs = model.Q[j,t]

# unit terminal condition
model.tc = Constraint(UNITS, rule = lambda model, j: model.Q[j,H] == 0)

# SolverFactory('glpk').solve(model).write()
# Out:
# cons : Size=1, Index=cons_index, Active=True
#     Key : Lower : Body                 : Upper : Active
#       1 :  -Inf : W[keg_line,kegger,0] :   1.0 :   True
# cons : Size=2, Index=cons_index, Active=True
#     Key : Lower : Body                                        : Upper : Active
#       1 :  -Inf :                        W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf : W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
# cons : Size=3, Index=cons_index, Active=True
#     Key : Lower : Body                                        : Upper : Active
#       1 :  -Inf :                        W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf : W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf : W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
# cons : Size=4, Index=cons_index, Active=True
#     Key : Lower : Body                                        : Upper : Active
#       1 :  -Inf :                        W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf : W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf : W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf : W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
# cons : Size=5, Index=cons_index, Active=True
#     Key : Lower : Body                                        : Upper : Active
#       1 :  -Inf :                        W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf : W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf : W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf : W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf : W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
# cons : Size=6, Index=cons_index, Active=True
#     Key : Lower : Body                                        : Upper : Active
#       1 :  -Inf :                        W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf : W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf : W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf : W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf : W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf : W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
# cons : Size=7, Index=cons_index, Active=True
#     Key : Lower : Body                                        : Upper : Active
#       1 :  -Inf :                        W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf : W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf : W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf : W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf : W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf : W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf : W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
# cons : Size=8, Index=cons_index, Active=True
#     Key : Lower : Body                                        : Upper : Active
#       1 :  -Inf :                        W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf : W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf : W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf : W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf : W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf : W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf : W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf : W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
# cons : Size=9, Index=cons_index, Active=True
#     Key : Lower : Body                                        : Upper : Active
#       1 :  -Inf :                        W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf : W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf : W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf : W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf : W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf : W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf : W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf : W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf : W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
# cons : Size=10, Index=cons_index, Active=True
#     Key : Lower : Body                                        : Upper : Active
#       1 :  -Inf :                        W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf : W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf : W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf : W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf : W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf : W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf : W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf : W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf : W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf : W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
# cons : Size=11, Index=cons_index, Active=True
#     Key : Lower : Body                                         : Upper : Active
#       1 :  -Inf :                         W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :  W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :  W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :  W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :  W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :  W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :  W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :  W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :  W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :  W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf : W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
# cons : Size=12, Index=cons_index, Active=True
#     Key : Lower : Body                                         : Upper : Active
#       1 :  -Inf :                         W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :  W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :  W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :  W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :  W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :  W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :  W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :  W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :  W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :  W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf : W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                      W[kettle,Kettle_drum,0] :   1.0 :   True
# cons : Size=13, Index=cons_index, Active=True
#     Key : Lower : Body                                              : Upper : Active
#       1 :  -Inf :                              W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :       W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :       W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :       W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :       W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :       W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :       W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :       W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :       W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :       W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :      W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                           W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf : W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
# cons : Size=14, Index=cons_index, Active=True
#     Key : Lower : Body                                              : Upper : Active
#       1 :  -Inf :                              W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :       W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :       W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :       W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :       W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :       W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :       W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :       W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :       W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :       W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :      W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                           W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf : W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf : W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
# cons : Size=15, Index=cons_index, Active=True
#     Key : Lower : Body                                              : Upper : Active
#       1 :  -Inf :                              W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :       W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :       W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :       W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :       W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :       W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :       W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :       W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :       W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :       W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :      W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                           W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf : W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf : W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf : W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
# cons : Size=16, Index=cons_index, Active=True
#     Key : Lower : Body                                              : Upper : Active
#       1 :  -Inf :                              W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :       W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :       W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :       W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :       W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :       W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :       W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :       W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :       W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :       W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :      W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                           W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf : W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf : W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf : W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf : W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
# cons : Size=17, Index=cons_index, Active=True
#     Key : Lower : Body                                              : Upper : Active
#       1 :  -Inf :                              W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :       W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :       W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :       W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :       W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :       W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :       W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :       W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :       W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :       W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :      W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                           W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf : W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf : W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf : W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf : W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf : W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
# cons : Size=18, Index=cons_index, Active=True
#     Key : Lower : Body                                              : Upper : Active
#       1 :  -Inf :                              W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :       W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :       W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :       W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :       W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :       W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :       W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :       W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :       W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :       W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :      W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                           W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf : W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf : W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf : W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf : W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf : W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf : W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
# cons : Size=19, Index=cons_index, Active=True
#     Key : Lower : Body                                              : Upper : Active
#       1 :  -Inf :                              W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :       W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :       W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :       W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :       W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :       W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :       W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :       W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :       W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :       W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :      W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                           W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf : W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf : W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf : W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf : W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf : W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf : W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf : W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
# cons : Size=20, Index=cons_index, Active=True
#     Key : Lower : Body                                              : Upper : Active
#       1 :  -Inf :                              W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :       W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :       W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :       W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :       W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :       W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :       W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :       W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :       W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :       W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :      W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                           W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf : W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf : W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf : W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf : W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf : W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf : W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf : W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
#      20 :  -Inf : W[kettle,Kettle_drum,7] + W[kettle,Kettle_drum,8] :   1.0 :   True
# cons : Size=21, Index=cons_index, Active=True
#     Key : Lower : Body                                              : Upper : Active
#       1 :  -Inf :                              W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :       W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :       W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :       W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :       W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :       W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :       W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :       W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :       W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :       W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :      W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                           W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf : W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf : W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf : W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf : W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf : W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf : W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf : W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
#      20 :  -Inf : W[kettle,Kettle_drum,7] + W[kettle,Kettle_drum,8] :   1.0 :   True
#      21 :  -Inf : W[kettle,Kettle_drum,8] + W[kettle,Kettle_drum,9] :   1.0 :   True
# cons : Size=22, Index=cons_index, Active=True
#     Key : Lower : Body                                               : Upper : Active
#       1 :  -Inf :                               W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :        W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :        W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :        W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :        W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :        W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :        W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :        W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :        W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :        W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :       W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                            W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf :  W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf :  W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf :  W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf :  W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf :  W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf :  W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf :  W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
#      20 :  -Inf :  W[kettle,Kettle_drum,7] + W[kettle,Kettle_drum,8] :   1.0 :   True
#      21 :  -Inf :  W[kettle,Kettle_drum,8] + W[kettle,Kettle_drum,9] :   1.0 :   True
#      22 :  -Inf : W[kettle,Kettle_drum,9] + W[kettle,Kettle_drum,10] :   1.0 :   True
# cons : Size=23, Index=cons_index, Active=True
#     Key : Lower : Body                                               : Upper : Active
#       1 :  -Inf :                               W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :        W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :        W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :        W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :        W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :        W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :        W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :        W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :        W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :        W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :       W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                            W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf :  W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf :  W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf :  W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf :  W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf :  W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf :  W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf :  W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
#      20 :  -Inf :  W[kettle,Kettle_drum,7] + W[kettle,Kettle_drum,8] :   1.0 :   True
#      21 :  -Inf :  W[kettle,Kettle_drum,8] + W[kettle,Kettle_drum,9] :   1.0 :   True
#      22 :  -Inf : W[kettle,Kettle_drum,9] + W[kettle,Kettle_drum,10] :   1.0 :   True
#      23 :  -Inf :                      W[separator,Separator_tank,0] :   1.0 :   True
# cons : Size=24, Index=cons_index, Active=True
#     Key : Lower : Body                                                          : Upper : Active
#       1 :  -Inf :                                          W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :                   W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :                   W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :                   W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :                   W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :                   W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :                   W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :                   W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :                   W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :                   W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :                  W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                                       W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf :             W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf :             W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf :             W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf :             W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf :             W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf :             W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf :             W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
#      20 :  -Inf :             W[kettle,Kettle_drum,7] + W[kettle,Kettle_drum,8] :   1.0 :   True
#      21 :  -Inf :             W[kettle,Kettle_drum,8] + W[kettle,Kettle_drum,9] :   1.0 :   True
#      22 :  -Inf :            W[kettle,Kettle_drum,9] + W[kettle,Kettle_drum,10] :   1.0 :   True
#      23 :  -Inf :                                 W[separator,Separator_tank,0] :   1.0 :   True
#      24 :  -Inf : W[separator,Separator_tank,0] + W[separator,Separator_tank,1] :   1.0 :   True
# cons : Size=25, Index=cons_index, Active=True
#     Key : Lower : Body                                                          : Upper : Active
#       1 :  -Inf :                                          W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :                   W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :                   W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :                   W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :                   W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :                   W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :                   W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :                   W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :                   W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :                   W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :                  W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                                       W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf :             W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf :             W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf :             W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf :             W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf :             W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf :             W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf :             W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
#      20 :  -Inf :             W[kettle,Kettle_drum,7] + W[kettle,Kettle_drum,8] :   1.0 :   True
#      21 :  -Inf :             W[kettle,Kettle_drum,8] + W[kettle,Kettle_drum,9] :   1.0 :   True
#      22 :  -Inf :            W[kettle,Kettle_drum,9] + W[kettle,Kettle_drum,10] :   1.0 :   True
#      23 :  -Inf :                                 W[separator,Separator_tank,0] :   1.0 :   True
#      24 :  -Inf : W[separator,Separator_tank,0] + W[separator,Separator_tank,1] :   1.0 :   True
#      25 :  -Inf : W[separator,Separator_tank,1] + W[separator,Separator_tank,2] :   1.0 :   True
# cons : Size=26, Index=cons_index, Active=True
#     Key : Lower : Body                                                          : Upper : Active
#       1 :  -Inf :                                          W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :                   W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :                   W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :                   W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :                   W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :                   W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :                   W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :                   W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :                   W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :                   W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :                  W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                                       W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf :             W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf :             W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf :             W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf :             W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf :             W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf :             W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf :             W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
#      20 :  -Inf :             W[kettle,Kettle_drum,7] + W[kettle,Kettle_drum,8] :   1.0 :   True
#      21 :  -Inf :             W[kettle,Kettle_drum,8] + W[kettle,Kettle_drum,9] :   1.0 :   True
#      22 :  -Inf :            W[kettle,Kettle_drum,9] + W[kettle,Kettle_drum,10] :   1.0 :   True
#      23 :  -Inf :                                 W[separator,Separator_tank,0] :   1.0 :   True
#      24 :  -Inf : W[separator,Separator_tank,0] + W[separator,Separator_tank,1] :   1.0 :   True
#      25 :  -Inf : W[separator,Separator_tank,1] + W[separator,Separator_tank,2] :   1.0 :   True
#      26 :  -Inf : W[separator,Separator_tank,2] + W[separator,Separator_tank,3] :   1.0 :   True
# cons : Size=27, Index=cons_index, Active=True
#     Key : Lower : Body                                                          : Upper : Active
#       1 :  -Inf :                                          W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :                   W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :                   W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :                   W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :                   W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :                   W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :                   W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :                   W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :                   W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :                   W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :                  W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                                       W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf :             W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf :             W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf :             W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf :             W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf :             W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf :             W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf :             W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
#      20 :  -Inf :             W[kettle,Kettle_drum,7] + W[kettle,Kettle_drum,8] :   1.0 :   True
#      21 :  -Inf :             W[kettle,Kettle_drum,8] + W[kettle,Kettle_drum,9] :   1.0 :   True
#      22 :  -Inf :            W[kettle,Kettle_drum,9] + W[kettle,Kettle_drum,10] :   1.0 :   True
#      23 :  -Inf :                                 W[separator,Separator_tank,0] :   1.0 :   True
#      24 :  -Inf : W[separator,Separator_tank,0] + W[separator,Separator_tank,1] :   1.0 :   True
#      25 :  -Inf : W[separator,Separator_tank,1] + W[separator,Separator_tank,2] :   1.0 :   True
#      26 :  -Inf : W[separator,Separator_tank,2] + W[separator,Separator_tank,3] :   1.0 :   True
#      27 :  -Inf : W[separator,Separator_tank,3] + W[separator,Separator_tank,4] :   1.0 :   True
# cons : Size=28, Index=cons_index, Active=True
#     Key : Lower : Body                                                          : Upper : Active
#       1 :  -Inf :                                          W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :                   W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :                   W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :                   W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :                   W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :                   W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :                   W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :                   W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :                   W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :                   W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :                  W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                                       W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf :             W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf :             W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf :             W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf :             W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf :             W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf :             W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf :             W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
#      20 :  -Inf :             W[kettle,Kettle_drum,7] + W[kettle,Kettle_drum,8] :   1.0 :   True
#      21 :  -Inf :             W[kettle,Kettle_drum,8] + W[kettle,Kettle_drum,9] :   1.0 :   True
#      22 :  -Inf :            W[kettle,Kettle_drum,9] + W[kettle,Kettle_drum,10] :   1.0 :   True
#      23 :  -Inf :                                 W[separator,Separator_tank,0] :   1.0 :   True
#      24 :  -Inf : W[separator,Separator_tank,0] + W[separator,Separator_tank,1] :   1.0 :   True
#      25 :  -Inf : W[separator,Separator_tank,1] + W[separator,Separator_tank,2] :   1.0 :   True
#      26 :  -Inf : W[separator,Separator_tank,2] + W[separator,Separator_tank,3] :   1.0 :   True
#      27 :  -Inf : W[separator,Separator_tank,3] + W[separator,Separator_tank,4] :   1.0 :   True
#      28 :  -Inf : W[separator,Separator_tank,4] + W[separator,Separator_tank,5] :   1.0 :   True
# cons : Size=29, Index=cons_index, Active=True
#     Key : Lower : Body                                                          : Upper : Active
#       1 :  -Inf :                                          W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :                   W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :                   W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :                   W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :                   W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :                   W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :                   W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :                   W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :                   W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :                   W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :                  W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                                       W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf :             W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf :             W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf :             W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf :             W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf :             W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf :             W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf :             W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
#      20 :  -Inf :             W[kettle,Kettle_drum,7] + W[kettle,Kettle_drum,8] :   1.0 :   True
#      21 :  -Inf :             W[kettle,Kettle_drum,8] + W[kettle,Kettle_drum,9] :   1.0 :   True
#      22 :  -Inf :            W[kettle,Kettle_drum,9] + W[kettle,Kettle_drum,10] :   1.0 :   True
#      23 :  -Inf :                                 W[separator,Separator_tank,0] :   1.0 :   True
#      24 :  -Inf : W[separator,Separator_tank,0] + W[separator,Separator_tank,1] :   1.0 :   True
#      25 :  -Inf : W[separator,Separator_tank,1] + W[separator,Separator_tank,2] :   1.0 :   True
#      26 :  -Inf : W[separator,Separator_tank,2] + W[separator,Separator_tank,3] :   1.0 :   True
#      27 :  -Inf : W[separator,Separator_tank,3] + W[separator,Separator_tank,4] :   1.0 :   True
#      28 :  -Inf : W[separator,Separator_tank,4] + W[separator,Separator_tank,5] :   1.0 :   True
#      29 :  -Inf : W[separator,Separator_tank,5] + W[separator,Separator_tank,6] :   1.0 :   True
# cons : Size=30, Index=cons_index, Active=True
#     Key : Lower : Body                                                          : Upper : Active
#       1 :  -Inf :                                          W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :                   W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :                   W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :                   W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :                   W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :                   W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :                   W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :                   W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :                   W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :                   W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :                  W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                                       W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf :             W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf :             W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf :             W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf :             W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf :             W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf :             W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf :             W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
#      20 :  -Inf :             W[kettle,Kettle_drum,7] + W[kettle,Kettle_drum,8] :   1.0 :   True
#      21 :  -Inf :             W[kettle,Kettle_drum,8] + W[kettle,Kettle_drum,9] :   1.0 :   True
#      22 :  -Inf :            W[kettle,Kettle_drum,9] + W[kettle,Kettle_drum,10] :   1.0 :   True
#      23 :  -Inf :                                 W[separator,Separator_tank,0] :   1.0 :   True
#      24 :  -Inf : W[separator,Separator_tank,0] + W[separator,Separator_tank,1] :   1.0 :   True
#      25 :  -Inf : W[separator,Separator_tank,1] + W[separator,Separator_tank,2] :   1.0 :   True
#      26 :  -Inf : W[separator,Separator_tank,2] + W[separator,Separator_tank,3] :   1.0 :   True
#      27 :  -Inf : W[separator,Separator_tank,3] + W[separator,Separator_tank,4] :   1.0 :   True
#      28 :  -Inf : W[separator,Separator_tank,4] + W[separator,Separator_tank,5] :   1.0 :   True
#      29 :  -Inf : W[separator,Separator_tank,5] + W[separator,Separator_tank,6] :   1.0 :   True
#      30 :  -Inf : W[separator,Separator_tank,6] + W[separator,Separator_tank,7] :   1.0 :   True
# cons : Size=31, Index=cons_index, Active=True
#     Key : Lower : Body                                                          : Upper : Active
#       1 :  -Inf :                                          W[keg_line,kegger,0] :   1.0 :   True
#       2 :  -Inf :                   W[keg_line,kegger,0] + W[keg_line,kegger,1] :   1.0 :   True
#       3 :  -Inf :                   W[keg_line,kegger,1] + W[keg_line,kegger,2] :   1.0 :   True
#       4 :  -Inf :                   W[keg_line,kegger,2] + W[keg_line,kegger,3] :   1.0 :   True
#       5 :  -Inf :                   W[keg_line,kegger,3] + W[keg_line,kegger,4] :   1.0 :   True
#       6 :  -Inf :                   W[keg_line,kegger,4] + W[keg_line,kegger,5] :   1.0 :   True
#       7 :  -Inf :                   W[keg_line,kegger,5] + W[keg_line,kegger,6] :   1.0 :   True
#       8 :  -Inf :                   W[keg_line,kegger,6] + W[keg_line,kegger,7] :   1.0 :   True
#       9 :  -Inf :                   W[keg_line,kegger,7] + W[keg_line,kegger,8] :   1.0 :   True
#      10 :  -Inf :                   W[keg_line,kegger,8] + W[keg_line,kegger,9] :   1.0 :   True
#      11 :  -Inf :                  W[keg_line,kegger,9] + W[keg_line,kegger,10] :   1.0 :   True
#      12 :  -Inf :                                       W[kettle,Kettle_drum,0] :   1.0 :   True
#      13 :  -Inf :             W[kettle,Kettle_drum,0] + W[kettle,Kettle_drum,1] :   1.0 :   True
#      14 :  -Inf :             W[kettle,Kettle_drum,1] + W[kettle,Kettle_drum,2] :   1.0 :   True
#      15 :  -Inf :             W[kettle,Kettle_drum,2] + W[kettle,Kettle_drum,3] :   1.0 :   True
#      16 :  -Inf :             W[kettle,Kettle_drum,3] + W[kettle,Kettle_drum,4] :   1.0 :   True
#      17 :  -Inf :             W[kettle,Kettle_drum,4] + W[kettle,Kettle_drum,5] :   1.0 :   True
#      18 :  -Inf :             W[kettle,Kettle_drum,5] + W[kettle,Kettle_drum,6] :   1.0 :   True
#      19 :  -Inf :             W[kettle,Kettle_drum,6] + W[kettle,Kettle_drum,7] :   1.0 :   True
#      20 :  -Inf :             W[kettle,Kettle_drum,7] + W[kettle,Kettle_drum,8] :   1.0 :   True
#      21 :  -Inf :             W[kettle,Kettle_drum,8] + W[kettle,Kettle_drum,9] :   1.0 :   True
#      22 :  -Inf :            W[kettle,Kettle_drum,9] + W[kettle,Kettle_drum,10] :   1.0 :   True
#      23 :  -Inf :                                 W[separator,Separator_tank,0] :   1.0 :   True
#      24 :  -Inf : W[separator,Separator_tank,0] + W[separator,Separator_tank,1] :   1.0 :   True
#      25 :  -Inf : W[separator,Separator_tank,1] + W[separator,Separator_tank,2] :   1.0 :   True
#      26 :  -Inf : W[separator,Separator_tank,2] + W[separator,Separator_tank,3] :   1.0 :   True
# ...
#      34 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  W[Reaction_B,Fermenter_2,0] + W[Reaction_A,Fermenter_2,0] + W[Reaction_C,Fermenter_2,0] :   1.0 :   True
#      35 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                        W[Reaction_B,Fermenter_2,0] + W[Reaction_B,Fermenter_2,1] + W[Reaction_A,Fermenter_2,0] + W[Reaction_A,Fermenter_2,1] + W[Reaction_C,Fermenter_2,0] + W[Reaction_C,Fermenter_2,1] :   1.0 :   True
#      36 :  -Inf :                                                                                                                                                                                                                                                                                                                                              W[Reaction_B,Fermenter_2,0] + W[Reaction_B,Fermenter_2,1] + W[Reaction_B,Fermenter_2,2] + W[Reaction_A,Fermenter_2,0] + W[Reaction_A,Fermenter_2,1] + W[Reaction_A,Fermenter_2,2] + W[Reaction_C,Fermenter_2,0] + W[Reaction_C,Fermenter_2,1] + W[Reaction_C,Fermenter_2,2] :   1.0 :   True
#      37 :  -Inf :                                                                                                                                                                                                                                                    W[Reaction_B,Fermenter_2,0] + W[Reaction_B,Fermenter_2,1] + W[Reaction_B,Fermenter_2,2] + W[Reaction_B,Fermenter_2,3] + W[Reaction_A,Fermenter_2,0] + W[Reaction_A,Fermenter_2,1] + W[Reaction_A,Fermenter_2,2] + W[Reaction_A,Fermenter_2,3] + W[Reaction_C,Fermenter_2,0] + W[Reaction_C,Fermenter_2,1] + W[Reaction_C,Fermenter_2,2] + W[Reaction_C,Fermenter_2,3] :   1.0 :   True
#      38 :  -Inf :                                                                                                                                                          W[Reaction_B,Fermenter_2,0] + W[Reaction_B,Fermenter_2,1] + W[Reaction_B,Fermenter_2,2] + W[Reaction_B,Fermenter_2,3] + W[Reaction_B,Fermenter_2,4] + W[Reaction_A,Fermenter_2,0] + W[Reaction_A,Fermenter_2,1] + W[Reaction_A,Fermenter_2,2] + W[Reaction_A,Fermenter_2,3] + W[Reaction_A,Fermenter_2,4] + W[Reaction_C,Fermenter_2,0] + W[Reaction_C,Fermenter_2,1] + W[Reaction_C,Fermenter_2,2] + W[Reaction_C,Fermenter_2,3] + W[Reaction_C,Fermenter_2,4] :   1.0 :   True
#      39 :  -Inf :                                                                                                                            W[Reaction_B,Fermenter_2,1] + W[Reaction_B,Fermenter_2,2] + W[Reaction_B,Fermenter_2,3] + W[Reaction_B,Fermenter_2,4] + W[Reaction_B,Fermenter_2,5] + W[Reaction_A,Fermenter_2,1] + W[Reaction_A,Fermenter_2,2] + W[Reaction_A,Fermenter_2,3] + W[Reaction_A,Fermenter_2,4] + W[Reaction_A,Fermenter_2,5] + W[Reaction_C,Fermenter_2,0] + W[Reaction_C,Fermenter_2,1] + W[Reaction_C,Fermenter_2,2] + W[Reaction_C,Fermenter_2,3] + W[Reaction_C,Fermenter_2,4] + W[Reaction_C,Fermenter_2,5] :   1.0 :   True
#      40 :  -Inf :                                                                                              W[Reaction_B,Fermenter_2,2] + W[Reaction_B,Fermenter_2,3] + W[Reaction_B,Fermenter_2,4] + W[Reaction_B,Fermenter_2,5] + W[Reaction_B,Fermenter_2,6] + W[Reaction_A,Fermenter_2,2] + W[Reaction_A,Fermenter_2,3] + W[Reaction_A,Fermenter_2,4] + W[Reaction_A,Fermenter_2,5] + W[Reaction_A,Fermenter_2,6] + W[Reaction_C,Fermenter_2,0] + W[Reaction_C,Fermenter_2,1] + W[Reaction_C,Fermenter_2,2] + W[Reaction_C,Fermenter_2,3] + W[Reaction_C,Fermenter_2,4] + W[Reaction_C,Fermenter_2,5] + W[Reaction_C,Fermenter_2,6] :   1.0 :   True
#      41 :  -Inf :                                                                W[Reaction_B,Fermenter_2,3] + W[Reaction_B,Fermenter_2,4] + W[Reaction_B,Fermenter_2,5] + W[Reaction_B,Fermenter_2,6] + W[Reaction_B,Fermenter_2,7] + W[Reaction_A,Fermenter_2,3] + W[Reaction_A,Fermenter_2,4] + W[Reaction_A,Fermenter_2,5] + W[Reaction_A,Fermenter_2,6] + W[Reaction_A,Fermenter_2,7] + W[Reaction_C,Fermenter_2,0] + W[Reaction_C,Fermenter_2,1] + W[Reaction_C,Fermenter_2,2] + W[Reaction_C,Fermenter_2,3] + W[Reaction_C,Fermenter_2,4] + W[Reaction_C,Fermenter_2,5] + W[Reaction_C,Fermenter_2,6] + W[Reaction_C,Fermenter_2,7] :   1.0 :   True
#      42 :  -Inf :                                  W[Reaction_B,Fermenter_2,4] + W[Reaction_B,Fermenter_2,5] + W[Reaction_B,Fermenter_2,6] + W[Reaction_B,Fermenter_2,7] + W[Reaction_B,Fermenter_2,8] + W[Reaction_A,Fermenter_2,4] + W[Reaction_A,Fermenter_2,5] + W[Reaction_A,Fermenter_2,6] + W[Reaction_A,Fermenter_2,7] + W[Reaction_A,Fermenter_2,8] + W[Reaction_C,Fermenter_2,0] + W[Reaction_C,Fermenter_2,1] + W[Reaction_C,Fermenter_2,2] + W[Reaction_C,Fermenter_2,3] + W[Reaction_C,Fermenter_2,4] + W[Reaction_C,Fermenter_2,5] + W[Reaction_C,Fermenter_2,6] + W[Reaction_C,Fermenter_2,7] + W[Reaction_C,Fermenter_2,8] :   1.0 :   True
#      43 :  -Inf :    W[Reaction_B,Fermenter_2,5] + W[Reaction_B,Fermenter_2,6] + W[Reaction_B,Fermenter_2,7] + W[Reaction_B,Fermenter_2,8] + W[Reaction_B,Fermenter_2,9] + W[Reaction_A,Fermenter_2,5] + W[Reaction_A,Fermenter_2,6] + W[Reaction_A,Fermenter_2,7] + W[Reaction_A,Fermenter_2,8] + W[Reaction_A,Fermenter_2,9] + W[Reaction_C,Fermenter_2,0] + W[Reaction_C,Fermenter_2,1] + W[Reaction_C,Fermenter_2,2] + W[Reaction_C,Fermenter_2,3] + W[Reaction_C,Fermenter_2,4] + W[Reaction_C,Fermenter_2,5] + W[Reaction_C,Fermenter_2,6] + W[Reaction_C,Fermenter_2,7] + W[Reaction_C,Fermenter_2,8] + W[Reaction_C,Fermenter_2,9] :   1.0 :   True
#      44 :  -Inf : W[Reaction_B,Fermenter_2,6] + W[Reaction_B,Fermenter_2,7] + W[Reaction_B,Fermenter_2,8] + W[Reaction_B,Fermenter_2,9] + W[Reaction_B,Fermenter_2,10] + W[Reaction_A,Fermenter_2,6] + W[Reaction_A,Fermenter_2,7] + W[Reaction_A,Fermenter_2,8] + W[Reaction_A,Fermenter_2,9] + W[Reaction_A,Fermenter_2,10] + W[Reaction_C,Fermenter_2,1] + W[Reaction_C,Fermenter_2,2] + W[Reaction_C,Fermenter_2,3] + W[Reaction_C,Fermenter_2,4] + W[Reaction_C,Fermenter_2,5] + W[Reaction_C,Fermenter_2,6] + W[Reaction_C,Fermenter_2,7] + W[Reaction_C,Fermenter_2,8] + W[Reaction_C,Fermenter_2,9] + W[Reaction_C,Fermenter_2,10] :   1.0 :   True
#      45 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      W[Heating_conversion,Mash Heater,0] :   1.0 :   True
#      46 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      W[Heating_conversion,Mash Heater,1] :   1.0 :   True
#      47 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      W[Heating_conversion,Mash Heater,2] :   1.0 :   True
#      48 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      W[Heating_conversion,Mash Heater,3] :   1.0 :   True
#      49 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      W[Heating_conversion,Mash Heater,4] :   1.0 :   True
#      50 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      W[Heating_conversion,Mash Heater,5] :   1.0 :   True
#      51 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      W[Heating_conversion,Mash Heater,6] :   1.0 :   True
#      52 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      W[Heating_conversion,Mash Heater,7] :   1.0 :   True
#      53 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      W[Heating_conversion,Mash Heater,8] :   1.0 :   True
#      54 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      W[Heating_conversion,Mash Heater,9] :   1.0 :   True
#      55 :  -Inf :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     W[Heating_conversion,Mash Heater,10] :   1.0 :   True
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-e59c4557a7cf> in <module>
#      39                 if tprime >= (t-p[i]+1-UNIT_TASKS[(j,i)]['Tclean']) and tprime <= t:
#      40                     lhs += model.W[i,j,tprime]
# ---> 41         model.cons.add(lhs <= 1)
#      42         model.cons.pprint()
#      43
#
# ~\anaconda3\lib\site-packages\pyomo\core\base\constraint.py in add(self, expr)
#    1176         next_idx = len(self._index) + 1
#    1177         self._index.add(next_idx)
# -> 1178         return self.__setitem__(next_idx, expr)
#    1179
#
# ~\anaconda3\lib\site-packages\pyomo\core\base\indexed_component.py in __setitem__(self, index, val)
#     475             obj = self._data.get(index, _NotFound)
#     476             if obj is _NotFound:
# --> 477                 return self._setitem_when_not_present(index, val)
#     478             else:
#     479                 return self._setitem_impl(index, obj, val)
#
# ~\anaconda3\lib\site-packages\pyomo\core\base\constraint.py in _setitem_when_not_present(self, index, value)
#     712
#     713     def _setitem_when_not_present(self, index, value):
# --> 714         if self._check_skip_add(index, value) is None:
#     715             return None
#     716         else:
#
# ~\anaconda3\lib\site-packages\pyomo\core\base\constraint.py in _check_skip_add(self, index, expr)
#     889                        expr and "Feasible" or "Infeasible",
#     890                        expr,
# --> 891                        _get_indexed_component_data_name(self,index)))
#     892
#     893         #
#
# ValueError: Invalid constraint expression. The constraint expression resolved to a trivial Boolean (True) instead of a Pyomo object. Please modify your rule to return Constraint.Feasible instead of True.
#
# Error thrown for Constraint 'cons[56]'

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Profitability

# %%
print("Value of State Inventories = {0:12.2f}".format(model.Value()))
print("  Cost of Unit Assignments = {0:12.2f}".format(model.Cost()))
print("             Net Objective = {0:12.2f}".format(model.Value() - model.Cost()))
# Out:
# Value of State Inventories =      2051.67
#   Cost of Unit Assignments =        14.00
#              Net Objective =      2037.67

# %% [markdown]
# ### Unit assignment

# %%
UnitAssignment = pd.DataFrame({j:[None for t in TIME] for j in UNITS}, index=TIME)

for t in TIME:
    for j in UNITS:
        for i in I[j]:
            for s in S_[i]:
                if t-p[i] >= 0:
                    if model.W[i,j,max(TIME[TIME <= t-p[i]])]() > 0:
                        UnitAssignment.loc[t,j] = None               
        for i in I[j]:
            if model.W[i,j,t]() > 0:
                UnitAssignment.loc[t,j] = (i,model.B[i,j,t]())

UnitAssignment
# Out:
#                          Reactor_1                       Heater  \
# 0               (Reaction_1, 80.0)                         None
# 1                             None             (Heating, 100.0)
# 2               (Reaction_2, 80.0)  (Heating, 6.66666666666566)
# 3                             None                         None
# 4               (Reaction_3, 40.0)                         None
# 5   (Reaction_2, 26.6666666666626)                         None
# 6                             None                         None
# 7               (Reaction_3, 80.0)                         None
# 8                             None                         None
# 9                             None                         None
# 10                            None                         None
#
#                          Reactor_2                           Still
# 0               (Reaction_1, 80.0)                            None
# 1                             None                            None
# 2               (Reaction_2, 80.0)                            None
# 3                             None                            None
# 4               (Reaction_3, 80.0)                            None
# 5               (Reaction_2, 80.0)             (Separation, 120.0)
# 6                             None                            None
# 7   (Reaction_3, 14.9999999999971)                            None
# 8                             None  (Separation, 94.9999999999971)
# 9                             None                            None
# 10                            None                            None

# %% [markdown]
# ### State inventories

# %%
pd.DataFrame([[model.S[s,t]() for s in STATES.keys()] for t in TIME], columns = STATES.keys(), index = TIME)
# Out:
#         Feed_A  Feed_B  Feed_C      Hot_A        Int_AB  Int_BC  Impure_E  \
# 0   500.000000   420.0   420.0   0.000000  0.000000e+00     0.0       0.0
# 1   400.000000   420.0   420.0   0.000000  0.000000e+00     0.0       0.0
# 2   393.333333   420.0   420.0  36.000000  0.000000e+00    64.0       0.0
# 3   393.333333   420.0   420.0  42.666667  0.000000e+00    64.0       0.0
# 4   393.333333   420.0   396.0  42.666667  0.000000e+00    64.0       0.0
# 5   393.333333   420.0   396.0   0.000000  0.000000e+00     0.0       0.0
# 6   393.333333   420.0   396.0   0.000000  8.842310e-14     0.0       0.0
# 7   393.333333   420.0   377.0   0.000000  0.000000e+00     0.0       0.0
# 8   393.333333   420.0   377.0   0.000000  0.000000e+00     0.0       0.0
# 9   393.333333   420.0   377.0   0.000000 -1.105289e-14     0.0       0.0
# 10  393.333333   420.0   377.0   0.000000  9.500000e+00     0.0       0.0
#
#      Product_1  Product_2
# 0     0.000000        0.0
# 1     0.000000        0.0
# 2     0.000000        0.0
# 3     0.000000        0.0
# 4    64.000000        0.0
# 5    64.000000        0.0
# 6    64.000000      108.0
# 7   106.666667      108.0
# 8   106.666667      108.0
# 9   106.666667      193.5
# 10  106.666667      193.5

# %%
plt.figure(figsize=(10,6))
for (s,idx) in zip(STATES.keys(),range(0,len(STATES.keys()))):
    plt.subplot(ceil(len(STATES.keys())/3),3,idx+1)
    tlast,ylast = 0,STATES[s]['initial']
    for (t,y) in zip(list(TIME),[model.S[s,t]() for t in TIME]):
        plt.plot([tlast,t,t],[ylast,ylast,y],'b')
        #plt.plot([tlast,t],[ylast,y],'b.',ms=10)
        tlast,ylast = t,y
    plt.ylim(0,1.1*C[s])
    plt.plot([0,H],[C[s],C[s]],'r--')
    plt.title(s)
plt.tight_layout()

# %% [markdown]
# ### Unit batch inventories

# %%
pd.DataFrame([[model.Q[j,t]() for j in UNITS] for t in TIME], columns = UNITS, index = TIME)
# Out:
#        Reactor_1        Heater  Reactor_2  Still
# 0   8.000000e+01  0.000000e+00       80.0    0.0
# 1   8.000000e+01  1.000000e+02       80.0    0.0
# 2   8.000000e+01  6.666667e+00       80.0    0.0
# 3   8.000000e+01  7.105427e-15       80.0    0.0
# 4   4.000000e+01  7.105427e-15       80.0    0.0
# 5   2.666667e+01  7.105427e-15       80.0  120.0
# 6   2.666667e+01  7.105427e-15       80.0   12.0
# 7   8.000000e+01  7.105427e-15       15.0    0.0
# 8   1.421085e-13  7.105427e-15        0.0   95.0
# 9  -3.029226e-27  7.105427e-15        0.0    9.5
# 10  0.000000e+00  0.000000e+00        0.0    0.0

# %% [markdown]
# ### Gannt chart

# %%
plt.figure(figsize=(12,6))

gap = H/500
idx = 1
lbls = []
ticks = []
for j in sorted(UNITS):
    idx -= 1
    for i in sorted(I[j]):
        idx -= 1
        ticks.append(idx)
        lbls.append("{0:s} -> {1:s}".format(j,i))
        plt.plot([0,H],[idx,idx],lw=20,alpha=.3,color='y')
        for t in TIME:
            if model.W[i,j,t]() > 0:
                plt.plot([t+gap,t+p[i]-gap], [idx,idx],'b', lw=20, solid_capstyle='butt')
                txt = "{0:.2f}".format(model.B[i,j,t]())
                plt.text(t+p[i]/2, idx, txt, color='white', weight='bold', ha='center', va='center')
plt.xlim(0,H)
plt.gca().set_yticks(ticks)
plt.gca().set_yticklabels(lbls);

# %% [markdown]
# ## Trace of events and states

# %%
sep = '\n--------------------------------------------------------------------------------------------\n'
print(sep)
print("Starting Conditions")
print("    Initial Inventories:")            
for s in STATES.keys():
        print("        {0:10s}  {1:6.1f} kg".format(s,STATES[s]['initial']))
        
units = {j:{'assignment':'None', 't':0} for j in UNITS}

for t in TIME:
    print(sep)
    print("Time =",t,"hr")
    print("    Instructions:")
    for j in UNITS:
        units[j]['t'] += 1
        # transfer from unit to states
        for i in I[j]:  
            for s in S_[i]:
                if t-P[(i,s)] >= 0:
                    amt = rho_[(i,s)]*model.B[i,j,max(TIME[TIME <= t - P[(i,s)]])]()
                    if amt > 0:
                        print("        Transfer", amt, "kg from", j, "to", s)
    for j in UNITS:
        # release units from tasks
        for i in I[j]:
            if t-p[i] >= 0:
                if model.W[i,j,max(TIME[TIME <= t-p[i]])]() > 0:
                    print("        Release", j, "from", i)
                    units[j]['assignment'] = 'None'
                    units[j]['t'] = 0
        # assign units to tasks             
        for i in I[j]:
            if model.W[i,j,t]() > 0:
                print("        Assign", j, "with capacity", Bmax[(i,j)], "kg to task",i,"for",p[i],"hours")
                units[j]['assignment'] = i
                units[j]['t'] = 1
        # transfer from states to starting tasks
        for i in I[j]:
            for s in S[i]:
                amt = rho[(i,s)]*model.B[i,j,t]()
                if amt > 0:
                    print("        Transfer", amt,"kg from", s, "to", j)
    print("\n    Inventories are now:")            
    for s in STATES.keys():
        print("        {0:10s}  {1:6.1f} kg".format(s,model.S[s,t]()))
    print("\n    Unit Assignments are now:")
    for j in UNITS:
        if units[j]['assignment'] != 'None':
            fmt = "        {0:s} performs the {1:s} task with a {2:.2f} kg batch for hour {3:f} of {4:f}"
            i = units[j]['assignment']
            print(fmt.format(j,i,model.Q[j,t](),units[j]['t'],p[i]))
            
print(sep)
print('Final Conditions')
print("    Final Inventories:")            
for s in STATES.keys():
        print("        {0:10s}  {1:6.1f} kg".format(s,model.S[s,H]()))
# Out:
# --------------------------------------------------------------------------------------------
#
# Starting Conditions
#     Initial Inventories:
#         Feed_A       500.0 kg
#         Feed_B       500.0 kg
#         Feed_C       500.0 kg
#         Hot_A          0.0 kg
#         Int_AB         0.0 kg
#         Int_BC         0.0 kg
#         Impure_E       0.0 kg
#         Product_1      0.0 kg
#         Product_2      0.0 kg
#
# --------------------------------------------------------------------------------------------
#
# Time = 0 hr
#     Instructions:
#         Assign Reactor_1 with capacity 80 kg to task Reaction_1 for 2 hours
#         Transfer 40.0 kg from Feed_B to Reactor_1
#         Transfer 40.0 kg from Feed_C to Reactor_1
#         Assign Reactor_2 with capacity 80 kg to task Reaction_1 for 2 hours
#         Transfer 40.0 kg from Feed_B to Reactor_2
#         Transfer 40.0 kg from Feed_C to Reactor_2
#
#     Inventories are now:
#         Feed_A       500.0 kg
#         Feed_B       420.0 kg
#         Feed_C       420.0 kg
#         Hot_A          0.0 kg
#         Int_AB         0.0 kg
#         Int_BC         0.0 kg
#         Impure_E       0.0 kg
#         Product_1      0.0 kg
#         Product_2      0.0 kg
#
#     Unit Assignments are now:
#         Reactor_1 performs the Reaction_1 task with a 80.00 kg batch for hour 1.000000 of 2.000000
#         Reactor_2 performs the Reaction_1 task with a 80.00 kg batch for hour 1.000000 of 2.000000
#
# --------------------------------------------------------------------------------------------
#
# Time = 1 hr
#     Instructions:
#         Assign Heater with capacity 100 kg to task Heating for 1 hours
#         Transfer 100.0 kg from Feed_A to Heater
#
#     Inventories are now:
#         Feed_A       400.0 kg
#         Feed_B       420.0 kg
#         Feed_C       420.0 kg
#         Hot_A          0.0 kg
#         Int_AB         0.0 kg
#         Int_BC         0.0 kg
#         Impure_E       0.0 kg
#         Product_1      0.0 kg
#         Product_2      0.0 kg
#
#     Unit Assignments are now:
#         Reactor_1 performs the Reaction_1 task with a 80.00 kg batch for hour 2.000000 of 2.000000
#         Heater performs the Heating task with a 100.00 kg batch for hour 1.000000 of 1.000000
#         Reactor_2 performs the Reaction_1 task with a 80.00 kg batch for hour 2.000000 of 2.000000
#
# --------------------------------------------------------------------------------------------
#
# Time = 2 hr
#     Instructions:
#         Transfer 80.0 kg from Reactor_1 to Int_BC
#         Transfer 100.0 kg from Heater to Hot_A
#         Transfer 80.0 kg from Reactor_2 to Int_BC
#         Release Reactor_1 from Reaction_1
#         Assign Reactor_1 with capacity 80 kg to task Reaction_2 for 2 hours
#         Transfer 32.0 kg from Hot_A to Reactor_1
#         Transfer 48.0 kg from Int_BC to Reactor_1
#         Release Heater from Heating
#         Assign Heater with capacity 100 kg to task Heating for 1 hours
#         Transfer 6.66666666666566 kg from Feed_A to Heater
#         Release Reactor_2 from Reaction_1
#         Assign Reactor_2 with capacity 80 kg to task Reaction_2 for 2 hours
#         Transfer 32.0 kg from Hot_A to Reactor_2
#         Transfer 48.0 kg from Int_BC to Reactor_2
#
#     Inventories are now:
#         Feed_A       393.3 kg
#         Feed_B       420.0 kg
#         Feed_C       420.0 kg
#         Hot_A         36.0 kg
#         Int_AB         0.0 kg
#         Int_BC        64.0 kg
#         Impure_E       0.0 kg
#         Product_1      0.0 kg
#         Product_2      0.0 kg
#
#     Unit Assignments are now:
#         Reactor_1 performs the Reaction_2 task with a 80.00 kg batch for hour 1.000000 of 2.000000
#         Heater performs the Heating task with a 6.67 kg batch for hour 1.000000 of 1.000000
#         Reactor_2 performs the Reaction_2 task with a 80.00 kg batch for hour 1.000000 of 2.000000
#
# --------------------------------------------------------------------------------------------
#
# Time = 3 hr
#     Instructions:
#         Transfer 6.66666666666566 kg from Heater to Hot_A
#         Release Heater from Heating
#         Transfer 6.06329801181964e-13 kg from Hot_A to Reactor_2
#         Transfer 9.09494701772946e-13 kg from Int_BC to Reactor_2
#
#     Inventories are now:
#         Feed_A       393.3 kg
#         Feed_B       420.0 kg
#         Feed_C       420.0 kg
#         Hot_A         42.7 kg
#         Int_AB         0.0 kg
#         Int_BC        64.0 kg
#         Impure_E       0.0 kg
#         Product_1      0.0 kg
#         Product_2      0.0 kg
#
#     Unit Assignments are now:
#         Reactor_1 performs the Reaction_2 task with a 80.00 kg batch for hour 2.000000 of 2.000000
#         Reactor_2 performs the Reaction_2 task with a 80.00 kg batch for hour 2.000000 of 2.000000
#
# --------------------------------------------------------------------------------------------
#
# Time = 4 hr
#     Instructions:
#         Transfer 48.0 kg from Reactor_1 to Int_AB
#         Transfer 32.0 kg from Reactor_1 to Product_1
#         Transfer 48.0 kg from Reactor_2 to Int_AB
#         Transfer 32.0 kg from Reactor_2 to Product_1
#         Release Reactor_1 from Reaction_2
#         Assign Reactor_1 with capacity 80 kg to task Reaction_3 for 1 hours
#         Transfer 8.0 kg from Feed_C to Reactor_1
#         Transfer 32.0 kg from Int_AB to Reactor_1
#         Release Reactor_2 from Reaction_2
#         Assign Reactor_2 with capacity 80 kg to task Reaction_3 for 1 hours
#         Transfer 16.0 kg from Feed_C to Reactor_2
#         Transfer 64.0 kg from Int_AB to Reactor_2
#
#     Inventories are now:
#         Feed_A       393.3 kg
#         Feed_B       420.0 kg
#         Feed_C       396.0 kg
#         Hot_A         42.7 kg
#         Int_AB         0.0 kg
#         Int_BC        64.0 kg
#         Impure_E       0.0 kg
#         Product_1     64.0 kg
#         Product_2      0.0 kg
#
#     Unit Assignments are now:
#         Reactor_1 performs the Reaction_3 task with a 40.00 kg batch for hour 1.000000 of 1.000000
#         Reactor_2 performs the Reaction_3 task with a 80.00 kg batch for hour 1.000000 of 1.000000
#
# --------------------------------------------------------------------------------------------
#
# Time = 5 hr
#     Instructions:
#         Transfer 40.0 kg from Reactor_1 to Impure_E
#         Transfer 9.09494701772946e-13 kg from Reactor_2 to Int_AB
#         Transfer 6.06329801181964e-13 kg from Reactor_2 to Product_1
#         Transfer 80.0 kg from Reactor_2 to Impure_E
#         Release Reactor_1 from Reaction_3
#         Assign Reactor_1 with capacity 80 kg to task Reaction_2 for 2 hours
#         Transfer 10.66666666666504 kg from Hot_A to Reactor_1
#         Transfer 15.99999999999756 kg from Int_BC to Reactor_1
#         Transfer 2.2737367544323605e-13 kg from Feed_C to Reactor_1
#         Transfer 9.094947017729442e-13 kg from Int_AB to Reactor_1
#         Release Reactor_2 from Reaction_3
#         Assign Reactor_2 with capacity 80 kg to task Reaction_2 for 2 hours
#         Transfer 32.0 kg from Hot_A to Reactor_2
#         Transfer 48.0 kg from Int_BC to Reactor_2
#         Assign Still with capacity 200 kg to task Separation for 2 hours
#         Transfer 120.0 kg from Impure_E to Still
#
#     Inventories are now:
#         Feed_A       393.3 kg
#         Feed_B       420.0 kg
#         Feed_C       396.0 kg
#         Hot_A          0.0 kg
#         Int_AB         0.0 kg
#         Int_BC         0.0 kg
#         Impure_E       0.0 kg
#         Product_1     64.0 kg
#         Product_2      0.0 kg
#
#     Unit Assignments are now:
#         Reactor_1 performs the Reaction_2 task with a 26.67 kg batch for hour 1.000000 of 2.000000
#         Reactor_2 performs the Reaction_2 task with a 80.00 kg batch for hour 1.000000 of 2.000000
#         Still performs the Separation task with a 120.00 kg batch for hour 1.000000 of 2.000000
#
# --------------------------------------------------------------------------------------------
#
# Time = 6 hr
#     Instructions:
#         Transfer 1.13686837721618e-12 kg from Reactor_1 to Impure_E
#         Transfer 108.0 kg from Still to Product_2
#         Transfer 1.13686837721618e-12 kg from Impure_E to Still
#
#     Inventories are now:
#         Feed_A       393.3 kg
#         Feed_B       420.0 kg
#         Feed_C       396.0 kg
#         Hot_A          0.0 kg
#         Int_AB         0.0 kg
#         Int_BC         0.0 kg
#         Impure_E       0.0 kg
#         Product_1     64.0 kg
#         Product_2    108.0 kg
#
#     Unit Assignments are now:
#         Reactor_1 performs the Reaction_2 task with a 26.67 kg batch for hour 2.000000 of 2.000000
#         Reactor_2 performs the Reaction_2 task with a 80.00 kg batch for hour 2.000000 of 2.000000
#         Still performs the Separation task with a 12.00 kg batch for hour 2.000000 of 2.000000
#
# --------------------------------------------------------------------------------------------
#
# Time = 7 hr
#     Instructions:
#         Transfer 15.99999999999756 kg from Reactor_1 to Int_AB
#         Transfer 10.66666666666504 kg from Reactor_1 to Product_1
#         Transfer 48.0 kg from Reactor_2 to Int_AB
#         Transfer 32.0 kg from Reactor_2 to Product_1
#         Transfer 1.023181539494562e-12 kg from Still to Product_2
#         Transfer 12.0 kg from Still to Int_AB
#         Release Reactor_1 from Reaction_2
#         Assign Reactor_1 with capacity 80 kg to task Reaction_3 for 1 hours
#         Transfer 16.0 kg from Feed_C to Reactor_1
#         Transfer 64.0 kg from Int_AB to Reactor_1
#         Release Reactor_2 from Reaction_2
#         Assign Reactor_2 with capacity 80 kg to task Reaction_3 for 1 hours
#         Transfer 2.99999999999942 kg from Feed_C to Reactor_2
#         Transfer 11.99999999999768 kg from Int_AB to Reactor_2
#         Release Still from Separation
#
#     Inventories are now:
#         Feed_A       393.3 kg
#         Feed_B       420.0 kg
#         Feed_C       377.0 kg
#         Hot_A          0.0 kg
#         Int_AB         0.0 kg
#         Int_BC         0.0 kg
#         Impure_E       0.0 kg
#         Product_1    106.7 kg
#         Product_2    108.0 kg
#
#     Unit Assignments are now:
#         Reactor_1 performs the Reaction_3 task with a 80.00 kg batch for hour 1.000000 of 1.000000
#         Reactor_2 performs the Reaction_3 task with a 15.00 kg batch for hour 1.000000 of 1.000000
#
# --------------------------------------------------------------------------------------------
#
# Time = 8 hr
#     Instructions:
#         Transfer 80.0 kg from Reactor_1 to Impure_E
#         Transfer 14.9999999999971 kg from Reactor_2 to Impure_E
#         Transfer 1.1368683772161802e-13 kg from Still to Int_AB
#         Release Reactor_1 from Reaction_3
#         Transfer 2.84217094304046e-14 kg from Feed_C to Reactor_1
#         Transfer 1.136868377216184e-13 kg from Int_AB to Reactor_1
#         Release Reactor_2 from Reaction_3
#         Assign Still with capacity 200 kg to task Separation for 2 hours
#         Transfer 94.9999999999971 kg from Impure_E to Still
#
#     Inventories are now:
#         Feed_A       393.3 kg
#         Feed_B       420.0 kg
#         Feed_C       377.0 kg
#         Hot_A          0.0 kg
#         Int_AB         0.0 kg
#         Int_BC         0.0 kg
#         Impure_E       0.0 kg
#         Product_1    106.7 kg
#         Product_2    108.0 kg
#
#     Unit Assignments are now:
#         Still performs the Separation task with a 95.00 kg batch for hour 1.000000 of 2.000000
#
# --------------------------------------------------------------------------------------------
#
# Time = 9 hr
#     Instructions:
#         Transfer 1.42108547152023e-13 kg from Reactor_1 to Impure_E
#         Transfer 85.4999999999974 kg from Still to Product_2
#         Transfer 1.42108547152023e-13 kg from Impure_E to Still
#
#     Inventories are now:
#         Feed_A       393.3 kg
#         Feed_B       420.0 kg
#         Feed_C       377.0 kg
#         Hot_A          0.0 kg
#         Int_AB        -0.0 kg
#         Int_BC         0.0 kg
#         Impure_E       0.0 kg
#         Product_1    106.7 kg
#         Product_2    193.5 kg
#
#     Unit Assignments are now:
#         Still performs the Separation task with a 9.50 kg batch for hour 2.000000 of 2.000000
#
# --------------------------------------------------------------------------------------------
#
# Time = 10 hr
#     Instructions:
#         Transfer 1.2789769243682068e-13 kg from Still to Product_2
#         Transfer 9.49999999999971 kg from Still to Int_AB
#         Transfer 6.0584517520973805e-28 kg from Feed_C to Reactor_1
#         Transfer 2.4233807008389522e-27 kg from Int_AB to Reactor_1
#         Release Still from Separation
#
#     Inventories are now:
#         Feed_A       393.3 kg
#         Feed_B       420.0 kg
#         Feed_C       377.0 kg
#         Hot_A          0.0 kg
#         Int_AB         9.5 kg
#         Int_BC         0.0 kg
#         Impure_E       0.0 kg
#         Product_1    106.7 kg
#         Product_2    193.5 kg
#
#     Unit Assignments are now:
#
# --------------------------------------------------------------------------------------------
#
# Final Conditions
#     Final Inventories:
#         Feed_A       393.3 kg
#         Feed_B       420.0 kg
#         Feed_C       377.0 kg
#         Hot_A          0.0 kg
#         Int_AB         9.5 kg
#         Int_BC         0.0 kg
#         Impure_E       0.0 kg
#         Product_1    106.7 kg
#         Product_2    193.5 kg

# %% [markdown]
# ## References
#
# Floudas, C. A., & Lin, X. (2005). Mixed integer linear programming in process scheduling: Modeling, algorithms, and applications. Annals of Operations Research, 139(1), 131-162.
#
# Harjunkoski, I., Maravelias, C. T., Bongers, P., Castro, P. M., Engell, S., Grossmann, I. E., ... & Wassick, J. (2014). Scope for industrial applications of production scheduling models and solution methods. Computers & Chemical Engineering, 62, 161-193.
#
# Kondili, E., Pantelides, C. C., & Sargent, R. W. H. (1993). A general algorithm for short-term scheduling of batch operations—I. MILP formulation. Computers & Chemical Engineering, 17(2), 211-227.
#
# Méndez, C. A., Cerdá, J., Grossmann, I. E., Harjunkoski, I., & Fahl, M. (2006). State-of-the-art review of optimization methods for short-term scheduling of batch processes. Computers & Chemical Engineering, 30(6), 913-946.
#
# Shah, N., Pantelides, C. C., & Sargent, R. W. H. (1993). A general algorithm for short-term scheduling of batch operations—II. Computational issues. Computers & Chemical Engineering, 17(2), 229-244.
#
# Wassick, J. M., & Ferrio, J. (2011). Extending the resource task network for industrial applications. Computers & chemical engineering, 35(10), 2124-2140.
